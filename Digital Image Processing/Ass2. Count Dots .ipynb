# %% [markdown]
# # Count The Black Dots

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def count_black_dots(image_path):
    image = cv2.imread(image_path)

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    _, binary = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY_INV)

    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    num_dots = len(contours)
    
    return num_dots

# %%
# Example usage
image_path = 'image.jpg'
image = cv2.imread(image_path,0)
num_dots = count_black_dots(image_path)
plt.imshow(image, cmap='gray')
plt.show()
print("Number of black dots:", num_dots)
# Out:
# Number of black dots: 360

# %%
def count_white_dots(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    inverted_gray = cv2.bitwise_not(gray)

    _, binary = cv2.threshold(inverted_gray, 240, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    num_dots = len(contours)

    return num_dots

# %%
# Example usage
image_path = 'image2.jpg'
num_dots = count_white_dots(image_path)
image = cv2.imread(image_path,0)
plt.imshow(image, cmap='gray')
plt.show()


print("Number of white dots:", num_dots)
# Out:
# Number of white dots: 1
