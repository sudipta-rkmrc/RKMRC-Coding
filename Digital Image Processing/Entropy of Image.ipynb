# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
img = cv.imread("CoverImages\lena.tiff")
im = cv.imread("CoverImages\lena.tiff",0)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
print(img)
# Out:
# [[[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  ...
#
#  [[ 60  18  84]
#   [ 60  18  84]
#   [ 58  27  92]
#   ...
#   [ 84  73 173]
#   [ 76  68 172]
#   [ 79  62 177]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]]

# %%
plt.imshow(im)
plt.xticks([])
plt.yticks([])
plt.title("Lena Gray Image")
plt.show()

# %%
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title("Lena BRG Image")
plt.show()

# %%
img1=cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
plt.imshow(img1)
plt.xticks([])
plt.yticks([])
plt.title("Lena RGB Image")
plt.show()

# %%
imvector = list(im.ravel())
gs = [x for x in range(256)]

# %%
fre = []
for x in gs:
    fre.append(imvector.count(x))

# %%
plt.plot(gs,fre)
plt.title("Manual Histogram")
plt.show()

# %%
hist = cv.calcHist([im],[0],None,[256],[0,256])

# %%
plt.title("Histogram via Using OpenCv Function")
plt.plot(hist)
plt.show()

# %%
fre1 = []
for i in range(256):
    fre1.append(fre[i]/(512*512))

# %%
plt.plot(gs,fre1)
plt.title("Manual Normalized Histogram")
plt.show()

# %% [markdown]
# ## Online

# %%
import cv2
import os
import numpy as np

# %%
def calculate_entropy(image):
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])
    hist_normalized = hist / np.sum(hist)
    entropy = -np.sum(hist_normalized * np.log2(hist_normalized + 1e-10))
    return entropy

# %%
image_directory = 'CoverImages'
image_list = []

# %%
for filename in os.listdir(image_directory):
    if filename.endswith(('.jpg', '.png', '.jpeg', '.tiff')):
        image_path = os.path.join(image_directory, filename)
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        entropy_value = calculate_entropy(img)
        image_list.append((filename, entropy_value))

# %%
sorted_image_list = sorted(image_list, key=lambda x: x[1])

# %%
for filename, entropy in sorted_image_list:
    print(f'Image: {filename}, Entropy: {entropy}')
# Out:
# Image: tank.tiff, Entropy: 5.495739936828613
# Image: airplane.tiff, Entropy: 6.702443599700928
# Image: fishingboat.tiff, Entropy: 7.191370487213135
# Image: house.tiff, Entropy: 7.233404159545898
# Image: splash.tiff, Entropy: 7.2534027099609375
# Image: baboon.tiff, Entropy: 7.358314514160156
# Image: lena.tiff, Entropy: 7.445040225982666
# Image: sailboat.tiff, Entropy: 7.484290599822998
# Image: elaine.tiff, Entropy: 7.505983352661133
# Image: peeper.tiff, Entropy: 7.593601226806641

# %%
fig, axes = plt.subplots(1, len(sorted_image_list), figsize=(15, 5))

for i, (filename, entropy) in enumerate(sorted_image_list):
    image_path = os.path.join(image_directory, filename)
    img = cv2.imread(image_path)
    axes[i].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axes[i].axis('off')
    axes[i].set_title(f'Entropy: {entropy:.2f}')

plt.show()

# %%
fig, axes = plt.subplots(1, len(sorted_image_list), figsize=(15, 5))

for i, (filename, entropy) in enumerate(sorted_image_list):
    image_path = os.path.join(image_directory, filename)
    img = cv2.imread(image_path)
    hist = cv2.calcHist([img], [0], None, [256], [0, 256])
    axes[i].plot(hist)
    axes[i].axis()
    axes[i].set_title(f'Entropy: {entropy:.2f}')

plt.show()

# %% [markdown]
# ## My Entropy Function

# %%
im = cv.imread("CoverImages\lena.tiff",0)
plt.imshow(im)
plt.xticks([])
plt.yticks([])
plt.title("Lena Gray Image")
plt.show()

# %%
import math as mt
def imageEntropy(p):
    h = 0.0
    for i in range(256):
        h = h + p[i]*mt.log2(p[i]+ 1e-10)
    h = -h
    return h

# %%
imvector = list(im.ravel())
gs = [x for x in range(256)]

# %%
fre = []
for x in gs:
    fre.append(imvector.count(x))

# %%
fre1 = []
for i in range(256):
    fre1.append(fre[i]/(512*512))

# %%
lenaEntropy = imageEntropy(fre1)

# %%
lenaEntropy
# Out:
# 7.445040459024629

# %%
plt.plot(gs,fre1)
plt.title("Normalized Histogram")
plt.show()

# %%
image_directory = 'CoverImages'
image_list = []

# %%
def calculate_entropy(im):
    imvector = list(im.ravel())
    gs = [x for x in range(256)]
    fre = []
    for x in gs:
        fre.append(imvector.count(x))
    fre1 = []
    for i in range(256):
        fre1.append(fre[i]/(512*512))
    return imageEntropy(fre1)

# %%
for filename in os.listdir(image_directory):
        image_path = os.path.join(image_directory, filename)
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        entropy_value = calculate_entropy(img)
        image_list.append((filename, entropy_value))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[163], line 5
#       2 image_path = os.path.join(image_directory, filename)
#       3 img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
# ----> 5 entropy_value = calculate_entropy(img)
#       6 image_list.append((filename, entropy_value))
#
# Cell In[162], line 6, in calculate_entropy(im)
#       4 fre = []
#       5 for x in gs:
# ----> 6     fre.append(imvector.count(x))
#       7 fre1 = []
#       8 for i in range(256):
#
# KeyboardInterrupt:

# %%
sorted_image_list = sorted(image_list, key=lambda x: x[1])

# %%
for filename, entropy in sorted_image_list:
    print(f'Image: {filename}, Entropy: {entropy}')
# Out:
# Image: tank.tiff, Entropy: 5.495739936828613
# Image: airplane.tiff, Entropy: 6.702443599700928
# Image: airplane.tiff, Entropy: 6.702443895499921
# Image: fishingboat.tiff, Entropy: 7.191370181280527
# Image: fishingboat.tiff, Entropy: 7.191370487213135
# Image: house.tiff, Entropy: 7.233404159545898
# Image: house.tiff, Entropy: 7.23340443219489
# Image: splash.tiff, Entropy: 7.2534027099609375
# Image: baboon.tiff, Entropy: 7.358314514160156
# Image: baboon.tiff, Entropy: 7.358314783907414
# Image: lena.tiff, Entropy: 7.445040225982666
# Image: lena.tiff, Entropy: 7.445040459024629
# Image: Barbara.tif, Entropy: 7.466426162530799
# Image: Barbara.tif, Entropy: 7.466426372528076
# Image: Goldhill.tif, Entropy: 7.477779602318312
# Image: Goldhill.tif, Entropy: 7.477779865264893
# Image: sailboat.tiff, Entropy: 7.484290599822998
# Image: elaine.tiff, Entropy: 7.505983352661133
# Image: elaine.tiff, Entropy: 7.5059836295520155
# Image: peeper.tiff, Entropy: 7.593600856097997
# Image: peeper.tiff, Entropy: 7.593601226806641

# %%
fig, axes = plt.subplots(1, len(sorted_image_list), figsize=(15, 5))

for i, (filename, entropy) in enumerate(sorted_image_list):
    image_path = os.path.join(image_directory, filename)
    img = cv2.imread(image_path)
    hist = cv2.calcHist([img], [0], None, [256], [0, 256])
    axes[i].plot(hist)
    axes[i].axis()
    axes[i].set_title(f'Entropy: {entropy:.2f}')

plt.show()

# %%
fig, axes = plt.subplots(1, len(sorted_image_list), figsize=(15, 5))

for i, (filename, entropy) in enumerate(sorted_image_list):
    image_path = os.path.join(image_directory, filename)
    img = cv2.imread(image_path)
    axes[i].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axes[i].axis('off')
    axes[i].set_title(f'Entropy: {entropy:.2f}')

plt.show()
